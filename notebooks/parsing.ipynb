# %%
import re
from os import path, listdir
import sys
import json

#
# Precompiled patterns for performance
#
time_pattern = re.compile("Date: (?P<data>[A-Z][a-z]+\, \d{1,2} [A-Z][a-z]+ \d{4} \d{2}\:\d{2}\:\d{2} \-\d{4} \([A-Z]{3}\))")
subject_pattern = re.compile("Subject: (?P<data>.*)")
sender_pattern = re.compile("From: (?P<data>.*)")
recipient_pattern = re.compile("To: (?P<data>.*)")
cc_pattern = re.compile("cc: (?P<data>.*)")
bcc_pattern = re.compile("bcc: (?P<data>.*)")
msg_start_pattern = re.compile("\n\n", re.MULTILINE)
msg_end_pattern = re.compile("\n+.*\n\d+/\d+/\d+ \d+:\d+ [AP]M", re.MULTILINE)

#
# Function: parse_email
# Arguments: pathname - relative path of folder/file to be parsed
#            orig     - whether this call is the original, used for writing to file
# Returns: none
# Effects: dumps json into file
#
feeds = []
users = {}
threads = {}
thread_users = {}
user_threads = {}
def parse_email(pathname, orig=True):
    if path.isdir(pathname):
        print(pathname)
        emails = []
        for child in listdir(pathname):
            # only parse visible files
            if child[0] != ".":
                parse_email(path.join(pathname, child), False)
    else:
        print("file %s" % pathname)
        with open(pathname) as TextFile:
            text = TextFile.read().replace("\r", "")
            try:
                time = time_pattern.search(text).group("data").replace("\n", "")
                subject = subject_pattern.search(text).group("data").replace("\n", "")

                sender = sender_pattern.search(text).group("data").replace("\n", "")

                recipient = recipient_pattern.search(text).group("data").split(", ")
                cc = cc_pattern.search(text).group("data").split(", ")
                bcc = bcc_pattern.search(text).group("data").split(", ")
                msg_start_iter = msg_start_pattern.search(text).end()
                try:
                    msg_end_iter = msg_end_pattern.search(text).start()
                    message = text[msg_start_iter:msg_end_iter]
                except AttributeError: # not a reply
                    message = text[msg_start_iter:]
                message = re.sub("[\n\r]", " ", message)
                message = re.sub("  +", " ", message)
            except AttributeError:
                logging.error("Failed to parse %s" % pathname) 
                return None
            # get user and thread ids
            sender_id = get_or_allocate_uid(sender)
            recipient_id = [get_or_allocate_uid(u.replace("\n", "")) for u in recipient if u!=""]
            cc_ids = [get_or_allocate_uid(u.replace("\n", "")) for u in cc if u!=""]
            bcc_ids = [get_or_allocate_uid(u.replace("\n", "")) for u in bcc if u!=""]
            thread_id = get_or_allocate_tid(subject)
        if thread_id not in thread_users:
            thread_users[thread_id] = set()
        # maintain list of users involved in thread
        users_involved = []
        users_involved.append(sender_id)
        users_involved.extend(recipient_id)
        users_involved.extend(cc_ids)
        users_involved.extend(bcc_ids)
        thread_users[thread_id] |= set(users_involved)
        # maintain list of threads where user is involved
        for user in set(users_involved):
            if user not in user_threads:
                user_threads[user] = set()
            user_threads[user].add(thread_id)
 
        entry =  {"time": time, "thread": thread_id, "sender": sender_id, "recipient": recipient_id, "cc": cc_ids, "bcc": bcc_ids, "message": message}
        feeds.append(entry)
    if orig:
        try:
            with open('messages.json', 'w') as f:
                json.dump(feeds, f)
            with open('users.json', 'w') as f:
                json.dump(users, f)
            with open('threads.json', 'w') as f:
                json.dump(threads, f)
            with open('thread-users.json', 'w') as f:
                for thread in thread_users:
                    thread_users[thread] = list(thread_users[thread])
                json.dump(thread_users, f)
            with open('user-threads.json', 'w') as f:
                for user in user_threads:
                    user_threads[user] = list(user_threads[user])
                json.dump(user_threads, f)
        except IOError:
            print("Unable to write to output files, aborting")
            exit(1)

#
# Function: get_or_allocated_uid
# Arguments: name - string of a user email
# Returns: unique integer id
#
def get_or_allocate_uid(name):
     if name not in users:
         users[name] = len(users)
     return users[name]

#
# Function: get_or_allocate_tid
# Arguments: name - string of email subject line
# Returns: unique integer id
#
def get_or_allocate_tid(name):
    parsed_name = re.sub("(RE|Re|FWD|Fwd): ", "", name)
    if parsed_name not in threads:
        threads[parsed_name] = len(threads)
    return threads[parsed_name]

# parse_email(sys.argv[1])

# %%
path_name = '/Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/'

# %%
parse_email(path_name)
# Out:
# /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/
# /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j
# /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/notes_inbox
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/notes_inbox/36.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/notes_inbox/19.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/notes_inbox/50.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/notes_inbox/3.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/notes_inbox/9.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/notes_inbox/13.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/notes_inbox/75.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/notes_inbox/35.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/notes_inbox/53.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/notes_inbox/59.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/notes_inbox/10.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/notes_inbox/76.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/notes_inbox/84.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/notes_inbox/42.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/notes_inbox/24.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/notes_inbox/67.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/notes_inbox/48.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/notes_inbox/41.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/notes_inbox/27.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/notes_inbox/64.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/notes_inbox/23.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/notes_inbox/83.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/notes_inbox/45.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/notes_inbox/60.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/notes_inbox/29.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/notes_inbox/20.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/notes_inbox/69.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/notes_inbox/46.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/notes_inbox/80.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/notes_inbox/63.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/notes_inbox/57.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/notes_inbox/4.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/notes_inbox/78.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/notes_inbox/31.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/notes_inbox/72.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/notes_inbox/14.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/notes_inbox/54.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/notes_inbox/7.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/notes_inbox/32.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/notes_inbox/38.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/notes_inbox/71.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/notes_inbox/17.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/notes_inbox/6.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/notes_inbox/55.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/notes_inbox/33.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/notes_inbox/70.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/notes_inbox/39.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/notes_inbox/16.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/notes_inbox/5.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/notes_inbox/56.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/notes_inbox/30.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/notes_inbox/79.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/notes_inbox/73.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/notes_inbox/15.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/notes_inbox/68.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/notes_inbox/21.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/notes_inbox/47.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/notes_inbox/81.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/notes_inbox/62.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/notes_inbox/22.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/notes_inbox/82.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/notes_inbox/44.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/notes_inbox/28.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/notes_inbox/61.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/notes_inbox/40.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/notes_inbox/26.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/notes_inbox/65.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/notes_inbox/43.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/notes_inbox/25.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/notes_inbox/66.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/notes_inbox/49.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/notes_inbox/34.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/notes_inbox/1.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/notes_inbox/52.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/notes_inbox/11.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/notes_inbox/58.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/notes_inbox/77.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/notes_inbox/37.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/notes_inbox/2.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/notes_inbox/51.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/notes_inbox/18.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/notes_inbox/12.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/notes_inbox/8.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/notes_inbox/74.
# /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/enron_europe
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/enron_europe/1.
# /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/personal
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/personal/3.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/personal/4.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/personal/5.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/personal/1.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/personal/2.
# /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/2000_conference
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/2000_conference/3.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/2000_conference/1.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/2000_conference/2.
# /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/vulcan_signs
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/vulcan_signs/3.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/vulcan_signs/1.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/vulcan_signs/2.
# /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/36.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/667.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/759.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/313.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/710.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/264.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/565.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/166.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/412.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/96.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/149.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/503.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/100.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/474.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/19.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/50.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/3.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/375.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/648.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/202.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/208.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/642.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/336.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/735.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/241.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/9.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/185.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/13.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/540.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/509.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/143.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/437.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/287.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/684.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/418.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/526.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/125.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/451.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/396.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/624.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/350.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/319.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/753.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/227.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/497.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/75.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/458.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/566.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/165.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/411.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/35.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/664.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/310.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/359.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/713.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/267.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/53.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/248.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/376.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/201.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/95.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/500.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/549.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/103.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/477.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/109.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/543.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/140.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/434.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/284.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/687.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/641.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/335.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/736.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/242.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/59.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/186.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/10.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/627.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/719.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/353.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/750.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/224.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/494.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/76.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/525.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/126.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/452.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/395.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/466.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/558.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/112.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/511.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/84.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/42.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/210.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/764.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/367.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/259.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/24.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/276.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/348.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/702.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/301.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/675.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/400.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/174.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/577.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/449.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/443.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/137.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/534.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/384.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/235.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/741.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/708.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/342.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/636.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/67.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/485.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/619.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/253.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/727.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/324.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/650.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/197.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/48.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/425.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/151.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/118.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/552.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/696.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/295.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/41.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/659.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/213.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/767.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/364.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/465.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/111.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/158.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/512.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/87.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/403.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/177.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/574.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/27.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/275.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/701.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/748.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/302.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/676.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/236.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/308.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/742.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/341.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/635.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/64.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/440.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/134.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/537.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/409.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/387.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/426.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/518.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/152.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/551.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/695.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/296.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/250.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/724.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/327.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/219.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/653.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/194.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/23.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/271.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/705.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/306.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/238.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/672.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/389.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/407.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/539.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/173.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/570.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/298.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/461.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/115.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/516.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/83.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/428.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/45.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/217.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/329.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/763.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/360.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/254.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/720.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/769.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/323.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/657.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/190.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/422.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/89.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/156.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/555.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/691.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/292.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/444.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/130.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/179.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/533.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/383.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/678.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/232.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/746.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/345.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/631.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/60.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/482.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/404.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/170.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/139.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/573.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/20.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/69.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/638.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/272.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/706.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/305.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/671.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/46.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/199.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/214.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/760.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/729.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/363.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/698.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/462.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/116.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/515.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/80.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/421.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/155.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/556.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/468.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/692.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/291.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/257.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/369.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/723.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/320.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/654.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/193.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/231.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/745.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/346.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/278.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/632.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/63.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/481.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/447.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/579.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/133.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/380.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/689.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/91.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/504.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/107.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/473.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/188.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/57.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/4.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/738.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/372.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/771.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/205.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/78.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/31.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/660.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/314.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/717.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/629.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/263.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/128.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/562.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/161.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/415.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/521.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/568.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/122.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/456.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/269.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/623.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/357.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/754.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/220.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/490.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/72.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/645.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/331.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/378.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/732.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/246.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/182.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/581.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/14.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/479.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/547.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/144.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/430.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/280.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/683.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/54.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/7.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/371.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/338.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/772.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/206.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/289.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/92.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/439.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/507.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/104.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/470.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/398.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/561.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/528.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/162.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/499.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/32.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/229.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/663.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/317.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/714.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/260.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/620.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/354.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/757.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/669.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/223.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/38.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/493.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/71.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/168.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/522.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/121.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/455.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/392.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/544.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/147.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/433.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/98.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/283.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/680.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/646.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/332.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/731.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/245.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/181.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/582.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/17.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/207.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/339.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/773.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/370.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/6.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/55.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/471.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/105.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/506.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/438.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/93.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/288.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/417.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/529.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/163.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/560.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/399.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/261.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/715.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/228.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/662.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/33.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/498.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/70.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/492.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/39.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/668.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/222.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/756.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/355.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/621.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/393.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/454.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/120.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/169.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/523.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/681.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/282.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/99.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/432.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/146.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/545.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/16.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/180.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/244.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/730.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/333.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/647.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/472.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/106.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/505.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/90.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/688.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/204.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/770.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/739.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/373.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/5.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/56.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/189.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/628.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/262.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/716.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/315.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/661.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/30.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/79.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/414.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/160.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/129.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/563.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/390.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/457.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/569.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/123.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/520.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/73.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/491.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/221.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/755.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/356.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/268.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/622.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/15.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/580.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/183.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/247.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/379.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/733.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/330.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/644.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/682.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/281.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/431.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/145.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/546.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/478.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/138.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/572.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/171.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/405.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/670.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/304.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/707.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/639.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/273.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/68.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/21.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/728.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/362.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/761.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/215.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/198.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/47.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/81.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/514.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/117.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/463.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/699.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/290.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/693.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/469.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/557.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/154.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/420.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/192.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/321.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/368.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/722.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/256.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/arnold-j/deleted_items/480.
# ...
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/reitmeyer-j/sent_items/9.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/reitmeyer-j/sent_items/13.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/reitmeyer-j/sent_items/75.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/reitmeyer-j/sent_items/35.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/reitmeyer-j/sent_items/10.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/reitmeyer-j/sent_items/24.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/reitmeyer-j/sent_items/67.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/reitmeyer-j/sent_items/41.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/reitmeyer-j/sent_items/27.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/reitmeyer-j/sent_items/64.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/reitmeyer-j/sent_items/23.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/reitmeyer-j/sent_items/29.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/reitmeyer-j/sent_items/20.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/reitmeyer-j/sent_items/69.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/reitmeyer-j/sent_items/63.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/reitmeyer-j/sent_items/4.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/reitmeyer-j/sent_items/78.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/reitmeyer-j/sent_items/31.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/reitmeyer-j/sent_items/72.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/reitmeyer-j/sent_items/14.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/reitmeyer-j/sent_items/7.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/reitmeyer-j/sent_items/32.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/reitmeyer-j/sent_items/38.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/reitmeyer-j/sent_items/71.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/reitmeyer-j/sent_items/17.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/reitmeyer-j/sent_items/6.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/reitmeyer-j/sent_items/33.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/reitmeyer-j/sent_items/70.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/reitmeyer-j/sent_items/16.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/reitmeyer-j/sent_items/5.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/reitmeyer-j/sent_items/30.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/reitmeyer-j/sent_items/79.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/reitmeyer-j/sent_items/73.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/reitmeyer-j/sent_items/15.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/reitmeyer-j/sent_items/68.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/reitmeyer-j/sent_items/21.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/reitmeyer-j/sent_items/62.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/reitmeyer-j/sent_items/22.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/reitmeyer-j/sent_items/28.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/reitmeyer-j/sent_items/40.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/reitmeyer-j/sent_items/26.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/reitmeyer-j/sent_items/65.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/reitmeyer-j/sent_items/25.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/reitmeyer-j/sent_items/66.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/reitmeyer-j/sent_items/34.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/reitmeyer-j/sent_items/1.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/reitmeyer-j/sent_items/11.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/reitmeyer-j/sent_items/77.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/reitmeyer-j/sent_items/37.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/reitmeyer-j/sent_items/2.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/reitmeyer-j/sent_items/18.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/reitmeyer-j/sent_items/12.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/reitmeyer-j/sent_items/8.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/reitmeyer-j/sent_items/74.
# /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/reitmeyer-j/jay_s_saved_stuff
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/reitmeyer-j/jay_s_saved_stuff/1.
# /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k
# /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/36.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/96.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/149.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/100.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/19.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/50.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/3.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/9.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/13.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/143.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/125.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/75.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/35.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/53.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/95.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/103.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/109.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/140.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/59.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/10.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/76.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/126.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/112.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/84.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/42.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/24.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/174.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/137.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/67.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/253.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/118.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/41.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/111.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/87.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/177.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/27.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/64.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/134.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/23.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/173.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/115.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/83.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/45.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/89.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/130.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/179.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/60.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/29.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/170.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/139.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/20.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/69.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/46.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/116.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/80.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/63.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/133.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/91.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/107.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/57.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/4.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/78.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/31.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/263.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/128.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/122.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/72.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/182.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/14.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/144.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/54.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/7.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/92.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/104.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/32.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/38.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/71.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/121.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/147.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/98.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/245.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/17.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/6.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/55.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/105.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/93.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/33.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/70.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/39.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/120.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/99.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/146.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/16.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/180.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/244.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/106.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/90.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/5.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/56.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/30.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/79.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/129.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/123.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/73.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/15.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/145.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/138.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/171.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/68.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/21.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/81.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/117.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/62.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/132.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/270.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/22.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/172.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/82.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/114.
# /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/cars
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/cars/3.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/cars/9.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/cars/10.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/cars/4.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/cars/7.
# file /Users/mhc/MIRI/Q4/TFM/tfm-nlp/data/raw/maildir/hyatt-k/personal/cars/6.
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
# ----> 1 parse_email(path_name)
#
# Input In [4], in parse_email(pathname, orig)
#      34     for child in listdir(pathname):
#      35         # only parse visible files
#      36         if child[0] != ".":
# ---> 37             parse_email(path.join(pathname, child), False)
#      38 else:
#      39     print("file %s" % pathname)
#
# Input In [4], in parse_email(pathname, orig)
#      34     for child in listdir(pathname):
#      35         # only parse visible files
#      36         if child[0] != ".":
# ---> 37             parse_email(path.join(pathname, child), False)
#      38 else:
#      39     print("file %s" % pathname)
#
#     [... skipping similar frames: parse_email at line 37 (1 times)]
#
# Input In [4], in parse_email(pathname, orig)
#      34     for child in listdir(pathname):
#      35         # only parse visible files
#      36         if child[0] != ".":
# ---> 37             parse_email(path.join(pathname, child), False)
#      38 else:
#      39     print("file %s" % pathname)
#
# Input In [4], in parse_email(pathname, orig)
#      39 print("file %s" % pathname)
#      40 with open(pathname) as TextFile:
# ---> 41     text = TextFile.read().replace("\r", "")
#      42     try:
#      43         time = time_pattern.search(text).group("data").replace("\n", "")
#
# File ~/anaconda3/envs/tfm/lib/python3.9/codecs.py:322, in BufferedIncrementalDecoder.decode(self, input, final)
#     319 def decode(self, input, final=False):
#     320     # decode input (taking the buffer into account)
#     321     data = self.buffer + input
# --> 322     (result, consumed) = self._buffer_decode(data, self.errors, final)
#     323     # keep undecoded input until the next call
#     324     self.buffer = data[consumed:]
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xe4 in position 1562: invalid continuation byte
